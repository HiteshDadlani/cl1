# %% [markdown]
# **DMV Practical No-6 **
#
#
#
# Data Aggregation
# Problem Statement: Analyzing Sales Performance by Region in a Retail Company
# Dataset: "Retail_Sales_Data.csv"
# Description: The dataset contains information about sales transactions in a retail company. It
# includes attributes such as transaction date, product category, quantity sold, and sales
# amount. The goal is to perform data aggregation to analyze the sales performance by region
# and identify the top-performing regions.
# Tasks to Perform:
# 1. Import the "Retail_Sales_Data.csv" dataset.
# 2. Explore the dataset to understand its structure and content.
# 3. Identify the relevant variables for aggregating sales data, such as region, sales
# amount, and product category.
# 4. Group the sales data by region and calculate the total sales amount for each region.
# 5. Create bar plots or pie charts to visualize the sales distribution by region.
# 6. Identify the top-performing regions based on the highest sales amount.
# 7. Group the sales data by region and product category to calculate the total sales
# amount for each combination.
# 8. Create stacked bar plots or grouped bar plots to compare the sales amounts across
# different regions and product categories.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"retail_sales_dataset_corrected.csv")
df
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.6+ MB

# %%
df.isnull().sum()#It gives the number of null values for each column in data
# Out:
# invoice_no        0
# customer_id       0
# gender            0
# age               0
# category          0
# quantity          0
# price             0
# payment_method    0
# invoice_date      0
# shopping_mall     0
# dtype: int64

# %%
df.describe()#it gives the statistical summary of numeric columns of the data like mean,max and min values of each numeric
#column,standard deviation etc
# Out:
#                 age      quantity         price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    689.256321
# std       14.990054      1.413025    941.184567
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %%
df.columns#printing the column names
# Out:
# Index(['invoice_no', 'customer_id', 'gender', 'age', 'category', 'quantity',
#        'price', 'payment_method', 'invoice_date', 'shopping_mall'],
#       dtype='object')

# %%
df['Sales Amount'] = df['quantity'] * df['price']#Calculating Sales Amount by multiplying quantity with price

# %%
df
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
df["shopping_mall"].unique()#it gives the unique values of shopping_mall
# Out:
# array(['Kanyon', 'Forum Istanbul', 'Metrocity', 'Metropol AVM',
#        'Istinye Park', 'Mall of Istanbul', 'Emaar Square Mall',
#        'Cevahir AVM', 'Viaport Outlet', 'Zorlu Center'], dtype=object)

# %%
sales_by_region = df.groupby('shopping_mall')['Sales Amount'].sum().reset_index()
#.reset_index() 
sales_by_region = sales_by_region.sort_values(by='Sales Amount', ascending=False)#Sorts in descending order
sales_by_region
# Out:
#        shopping_mall  Sales Amount
# 5   Mall of Istanbul   50872481.68
# 4             Kanyon   50554231.10
# 6          Metrocity   37302787.33
# 7       Metropol AVM   25379913.19
# 3       Istinye Park   24618827.68
# 9       Zorlu Center   12901053.82
# 0        Cevahir AVM   12645138.20
# 8     Viaport Outlet   12521339.72
# 1  Emaar Square Mall   12406100.29
# 2     Forum Istanbul   12303921.24

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.bar(sales_by_region['shopping_mall'], sales_by_region['Sales Amount'], color='skyblue')
plt.title("Total Sales Amount by Shopping Mall")
plt.xlabel("Shopping Mall")
plt.ylabel("Total Sales Amount")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

#The y axis has le7 written on the top it means multiplied by 10 raise to 7(x10 raise to 7)
#Means if y axis value is 1 it means 1x10 raise to 7

# %%
plt.figure(figsize=(8,8))
plt.pie(sales_by_region['Sales Amount'],
        labels=sales_by_region['shopping_mall'],
        autopct='%1.1f%%',#ensures there is only 1 umber after decimal
        startangle=90)
plt.title("Sales Distribution by Shopping Mall")
plt.axis("equal")#Make the scale on the X-axis and Y-axis equal, so one unit on
#the X-axis is the same length as one unit on the Y-axis.
#In simple term it ensures that the pie chart is in circle shape and not oval
plt.show()

# %%
top_regions = sales_by_region.head()
print("Top Performing Regions")
top_regions
# Out:
# Top Performing Regions
#       shopping_mall  Sales Amount
# 5  Mall of Istanbul   50872481.68
# 4            Kanyon   50554231.10
# 6         Metrocity   37302787.33
# 7      Metropol AVM   25379913.19
# 3      Istinye Park   24618827.68

# %%
region_category_sales = df.groupby(['shopping_mall', 'category'])['Sales Amount'].sum().unstack(fill_value=0)
#df.groupby(['shopping_mall', 'category']).This groups your data by two columns:
#shopping_mall → each mall (region)
#category → each product category (like Clothing, Books, Electronics, etc.)
#So now we are organizing the data by every mall + category combination.

#.unstack(fill_value=0)Converts the grouped result (which has a MultiIndex) into a table format:
#Rows → shopping malls
#Columns → product categories
#Values → total sales amounts
#fill_value=0 means if a mall doesn’t have sales for a certain category, it will show 0 instead of a blank or NaN.

region_category_sales
# Out:
# category               Books     Clothing   Cosmetics  Food & Beverage  \
# shopping_mall
# Cevahir AVM         44541.00   5706321.28   321214.00         44010.45
# Emaar Square Mall   41995.80   5590490.40   338941.76         40610.95
# Forum Istanbul      42056.40   5792444.24   353172.76         39162.24
# Istinye Park        76083.30  11253900.24   655357.88         85918.44
# Kanyon             163029.15  22609527.60  1369550.78        166497.05
# Mall of Istanbul   172240.35  22947417.68  1367517.78        171177.90
# Metrocity          125911.65  17226692.56   991860.04        129902.74
# Metropol AVM        83718.90  11568084.00   680770.38         88638.04
# Viaport Outlet      39632.40   5604594.16   347439.70         41662.18
# Zorlu Center        45343.95   5697318.88   367037.82         41955.06
#
# category                 Shoes   Souvenir  Technology       Toys
# shopping_mall
# Cevahir AVM         3243918.85   29723.82   3051300.0  204108.80
# ...

# %%
region_category_sales.plot(kind='bar', stacked=True, figsize=(11,6))
plt.title("Sales Comparison by Region and Product Category")
plt.xlabel("Region")
plt.ylabel("Total Sales Amount")
plt.legend(title='Category', bbox_to_anchor=(1.02, 1), loc='upper left')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [raw]
# That's a great approach to preparing for your practical exam! Yes, I understand the provided Python code, which performs **data aggregation and visualization** to analyze sales performance by region and product category in a retail dataset.
#
# Here is a detailed explanation of the code, followed by potential questions and answers for your preparation.
#
# ***
#
# ## 📚 Code Explanation: Analyzing Sales Performance
#
# The code executes a series of steps to fulfill the **DMV Practical No-6: Data Aggregation** problem statement.
#
# ### 1. Setup and Data Loading (Cells 1-6)
#
# * **Imports (Cell 1):** Imports `pandas` (as `pd`) for data manipulation and `matplotlib.pyplot` (as `plt`) for visualization.
# * **Data Loading and Initial View (Cell 2):**
#     * `df = pd.read_csv(r"retail_sales_dataset_corrected.csv")` loads the dataset into a DataFrame named `df`.
#     * `df` displays the first and last few rows of the DataFrame, showing columns like `invoice_no`, `customer_id`, `gender`, `age`, `category`, `quantity`, `price`, `payment_method`, `invoice_date`, and `shopping_mall`.
# * **Data Exploration (`.info()`, `.isnull().sum()`, `.describe()`) (Cells 3-5):**
#     * `df.info()` confirms the DataFrame has **99,457 entries** and 10 columns, with no missing (null) values in any column. It also shows the data types (e.g., `object` for strings, `int64` for integers, `float64` for decimals).
#     * `df.isnull().sum()` explicitly confirms the **absence of null values** (all counts are 0).
#     * `df.describe()` provides a statistical summary of the numeric columns (`age`, `quantity`, `price`), showing counts, mean, standard deviation, min, max, and quartiles.
# * **Column Names (`.columns`) (Cell 6):** `df.columns` simply prints the names of all columns.
#
# ### 2. Calculating the Sales Amount (Cells 7-9)
#
# * **Calculate `Sales Amount` (Cell 7):**
#     * `df['Sales Amount'] = df['quantity'] * df['price']` creates a **new column** by multiplying the `quantity` sold by the `price` of the item for every row (transaction). This calculated column is the primary metric for sales analysis.
# * **View Updated DataFrame (Cell 8):** Displays the DataFrame, now including the new `Sales Amount` column.
# * **Identify Unique Regions (Cell 9):** `df["shopping_mall"].unique()` lists the 10 distinct values in the `shopping_mall` column, which are treated as the **regions** in this analysis.
#
# ### 3. Aggregation by Region and Visualization (Cells 10-13)
#
# * **Group and Aggregate by Region (Cell 10):**
#     * `sales_by_region = df.groupby('shopping_mall')['Sales Amount'].sum().reset_index()`
#         * **Grouping:** Groups all transactions based on the `shopping_mall` (region).
#         * **Aggregation:** Calculates the **sum** of the `Sales Amount` for each unique mall.
#         * **Reset Index:** Converts the result from a Pandas Series (where `shopping_mall` was the index) back into a DataFrame with `shopping_mall` and `Sales Amount` as regular columns.
#     * `sales_by_region = sales_by_region.sort_values(by='Sales Amount', ascending=False)` sorts the resulting DataFrame to list regions from **highest to lowest total sales**.
#     * The result is displayed, showing the total sales for all 10 shopping malls.
# * **Bar Plot Visualization (Cell 11):**
#     * Creates a bar plot to visually compare the total sales across the 10 shopping malls.
#     * The `y` axis shows "Total Sales Amount" (note: the output indicates the scale is in **$10^7$**, so a value of 1.0 means 10,000,000).
#     * **Finding Top Regions (Cell 13):**
#     * `top_regions = sales_by_region.head()` selects and displays the top 5 rows (malls) from the sorted `sales_by_region` DataFrame, clearly identifying the **top-performing regions**.
# * **Pie Chart Visualization (Cell 12):**
#     * Creates a pie chart to visualize the **sales distribution** (market share) of each shopping mall as a percentage of the total sales.
#     * `autopct='%1.1f%%'` formats the slices to show one decimal place.
#     * `plt.axis("equal")` ensures the pie chart is perfectly circular.
#
# ### 4. Aggregation and Visualization by Region and Category (Cells 14-15)
#
# * **Group and Aggregate by Region and Category (Cell 14):**
#     * `region_category_sales = df.groupby(['shopping_mall', 'category'])['Sales Amount'].sum().unstack(fill_value=0)`
#         * **Double Grouping:** Groups the data by both `shopping_mall` and `category`.
#         * **Aggregation:** Calculates the total `Sales Amount` for **each unique combination** (e.g., 'Kanyon' and 'Clothing').
#         * **Unstacking:** Pivots the table so that `shopping_mall` remains the index (rows) and `category` values become the **columns**. Any missing combination is filled with `0`.
#     * The resulting DataFrame is displayed, which is ready for cross-comparison.
# * **Stacked Bar Plot Visualization (Cell 15):**
#     * `region_category_sales.plot(kind='bar', stacked=True, figsize=(11,6))`
#     * Creates a **stacked bar plot** where each bar represents a `shopping_mall` (region).
#     * The height of the bar is the mall's total sales. The different colored segments within the bar represent the sales contribution of each `category`.
#     * This visualization allows for direct **comparison of total sales across regions** and **comparison of product performance within each region**.
#
# ***
#
# ## ❓ Practical Exam Q&A Preparation
#
# Use these questions and answers to prepare for your viva or practical questions.
#
# ### General & Data Preparation Questions
#
# 1.  **Q: What is the primary goal of this entire analysis?**
#     * **A:** The goal is to perform **data aggregation** to analyze sales performance, specifically by **region** (shopping mall) and **product category**, to identify top-performing regions and compare category contributions.
#
# 2.  **Q: Which columns are used as the "region" and "sales amount" variables, as mentioned in the problem statement?**
#     * **A:** The **region** variable is the **`shopping_mall`** column. The **sales amount** is the newly calculated **`Sales Amount`** column (which is `quantity * price`).
#
# 3.  **Q: How did you calculate the `Sales Amount` column, and why was it necessary?**
#     * **A:** It was calculated by multiplying the **`quantity`** column by the **`price`** column for each transaction (`df['Sales Amount'] = df['quantity'] * df['price']`). It was necessary because the original dataset only provided unit price and quantity; the total monetary value of the sale had to be computed before aggregation.
#
# 4.  **Q: What is the purpose of checking for null values using `df.isnull().sum()`?**
#     * **A:** To ensure data **quality and integrity**. Null values (missing data) can cause errors or produce inaccurate results when performing calculations or aggregations. In this case, the check confirmed there are no missing values, so no cleaning was required.
#
# ### Aggregation and Visualization Questions
#
# 5.  **Q: How did you calculate the total sales for each region (shopping mall)?**
#     * **A:** I used the Pandas **`.groupby()`** method on the **`shopping_mall`** column and applied the **`.sum()`** aggregation function to the **`Sales Amount`** column: `df.groupby('shopping_mall')['Sales Amount'].sum()`.
#
# 6.  **Q: Which region is the top performer in terms of total sales amount?**
#     * **A:** Based on the results, **Mall of Istanbul** is the top-performing region, followed closely by **Kanyon**.
#
# 7.  **Q: Why did you use both a bar plot and a pie chart to visualize sales by region?**
#     * **A:** The **bar plot** is best for visually comparing the *magnitude* (actual size) of sales across different regions. The **pie chart** is best for visualizing the *proportion* (percentage/market share) of each region's sales relative to the total.
#
# 8.  **Q: What does the `plt.axis("equal")` command do when plotting the pie chart?**
#     * **A:** It ensures that the aspect ratio of the plot is **equal**, which guarantees that the pie chart is rendered as a perfect **circle** instead of an oval, preventing visual distortion of the proportions.
#
# 9.  **Q: Explain the `unstack(fill_value=0)` function in the multi-level aggregation.**
#     * **A:** After grouping by `shopping_mall` and `category`, the data is hierarchical. The **`.unstack()`** function pivots the inner level of the index (`category`) into separate **columns**. `fill_value=0` ensures that if a mall had no sales for a specific category, that cell is filled with 0 instead of `NaN` (Not a Number), which is cleaner for analysis and plotting.
#
# 10. **Q: What is the benefit of using a stacked bar plot (Cell 15)?**
#     * **A:** The stacked bar plot is powerful because it allows us to see **two things at once**:
#         1.  The **total sales** for each region (the total height of the bar).
#         2.  The **contribution of each product category** (the colored segments) to that region's total sales. This helps compare the internal sales mix of different malls.
#
# 11. **Q: By looking at the stacked bar plot, what seems to be the most popular product category across most regions?**
#     * **A:** Visually, the **Clothing** category (likely the blue segment) and **Shoes** category (likely the orange segment) appear to make up the largest portion of sales in almost all shopping malls, indicating they are the company's highest-revenue product lines.
#
# ***
#
# Would you like me to focus on explaining any specific section of the code or generate more questions on a particular topic?
